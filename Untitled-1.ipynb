# %%
import pandas as pd
from geopy.geocoders import Nominatim

# Read the CSV file
csv_file = 'coordenadas_v2.csv'
df = pd.read_csv(csv_file)

# Initialize the geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get address from latitude and longitude
def get_address(row):
    try:
        location = geolocator.reverse((row['Latitude'], row['Longitude']), exactly_one=True)
        return location.address if location else None
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
# Apply the get_address function to each row in the DataFrame
df['Address'] = df.apply(get_address, axis=1)

# Save the updated DataFrame to a new CSV file
output_csv_file = 'locations_with_addresses.csv'
df.to_csv(output_csv_file, index=False)

print(f"Addresses have been added to '{output_csv_file}'.")

# %%
from geopy import distance
import pandas as pd
from datetime import datetime
import time

startTime = datetime.now()
print(datetime.now() - startTime)
lat1 = 18.4586700000
long1 = -65.9496523000

def distance_2points(row):
    coord1 = (lat1, long1)
    # convert the latitude and longitude to floats
    row['Latitude'] = float(row['Latitude'])
    row['Longitude'] = float(row['Longitude'])
    # create a tuple from the lat and long
    coord2 = (row['Latitude'], row['Longitude'])
    # return the distance in miles
    results = distance.distance(coord1, coord2).miles
    #print(f"Distance: {results}")
    return results

df = pd.read_csv('coordenadas_v2.csv')
df = df.head(12000)
df['distance'] = df.apply(lambda row: distance_2points(row), axis=1)
print(datetime.now() - startTime)

# get points within 5 miles
miles = 5
new_df = df[df['distance'] <= miles]
print(new_df)

# %%
import requests
import urllib.parse
import pandas as pd
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="my_user_agent")

df = pd.read_csv('coordenadas_v3.csv')

# function to get address from latitude and longitude
def get_address(row):
    # convert the latitude and longitude to floats
    row['Latitude'] = float(row['Latitude'])
    row['Longitude'] = float(row['Longitude'])
    # create a tuple from the lat and long
    location = (row['Latitude'], row['Longitude'])
    # reverse geocode the coordinates
    results = geolocator.reverse(location, exactly_one=True)
    # print the row number and address
    print(f"{row.name}: {results}")
    return results.address if results else None
  

#new_df = df.head(100)  
# apply the get_address function to each row in the DataFrame
new_df['Address'] = new_df.apply(get_address, axis=1)
# save the updated DataFrame to a new CSV file
new_df.to_csv('locations_with_addresses.csv', index=False)
# Out:
# 0: None
# 1: None
# 2: 55, Calle Sirena, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 3: Calle Palma, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 4: Calle Fragata, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 5: Calle Fragata, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 6: Jobos, Guayama, Puerto Rico, 00704, United States
# 7: Calle Espada, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 8: Calle 6, Nuevo Amanecer, Machete, Guayama, Puerto Rico, 00785, United States
# 9: Nuevo Amanecer, Machete, Guayama, Puerto Rico, 00785, United States
# 10: Calle A, Carenero, Guánica, Puerto Rico, 00653, United States
# 11: Nuevo Amanecer, Machete, Guayama, Puerto Rico, 00785, United States
# 12: Calle 2, Barrancas, Machete, Guayama, Puerto Rico, 00785, United States
# 13: Calle 2, Barrancas, Machete, Guayama, Puerto Rico, 00785, United States
# 14: Calle 1, Barrancas, Machete, Guayama, Puerto Rico, 00785, United States
# 15: Calle B, Comunidad Puerto de Jobos, Jobos, Guayama, Puerto Rico, 00704, United States
# 16: Calle B, Comunidad Puerto de Jobos, Jobos, Guayama, Puerto Rico, 00704, United States
# 17: 285, Calle Brisas, Montesoria I, Aguirre, Salinas, Puerto Rico, 00704, United States
# 18: 548, Calle Amarilis, Comunidad Miramar, Jobos, Guayama, Puerto Rico, 00784, United States
# 19: 860, Calle Dalia, Comunidad Miramar, Jobos, Guayama, Puerto Rico, 00784, United States
# 20: 298, Calle Laguna, Montesoria I, Aguirre, Salinas, Puerto Rico, 00704, United States
# 21: 1008, Calle Geranio, Comunidad Miramar, Jobos, Guayama, Puerto Rico, 00784, United States
# 22: Calle B, Machete, Guayama, Puerto Rico, 00785, United States
# 23: 186, Calle Principal, Montesoria I, Aguirre, Salinas, Puerto Rico, 00704, United States
# 24: 4, Calle E, Barriada Santa Ana, Jobos, Guayama, Puerto Rico, 00784, United States
# 25: 199, Calle Marlín, Montesoria II y III, Aguirre, Salinas, Puerto Rico, 00704, United States
# 26: 187, Calle Marlín, Montesoria II y III, Aguirre, Salinas, Puerto Rico, 00704, United States
# 27: 177, Calle Mar y Sol, Montesoria II y III, Aguirre, Salinas, Puerto Rico, 00704, United States
# 28: 129, Calle Coral, Montesoria II y III, Aguirre, Salinas, Puerto Rico, 00704, United States
# 29: Calle 6, Jauca I, Santa Isabel, Puerto Rico, 00757, United States
# 30: Urb. Vista del Sol, Machete, Guayama, Puerto Rico, 00785, United States
# 31: Jauca I, Santa Isabel, Puerto Rico, 00757, United States
# 32: Urb. Vista del Sol, Machete, Guayama, Puerto Rico, 00785, United States
# 33: Calle B, Playita, Urb. Marbella, Aguirre, Salinas, Puerto Rico, 00787, United States
# 34: Calle Vista Hermosa, Machete, Guayama, Puerto Rico, 00785, United States
# 35: 427, Calle B, Barriada Santa Ana, Jobos, Guayama, Puerto Rico, 00784, United States
# 36: 28, Calle Luis Muñoz Rivera, San Felipe (Arizona), Barrio Pueblo, Arroyo, Puerto Rico, 00714, United States
# 37: Calle Auyama, Urb. Vista del Sol, Machete, Guayama, Puerto Rico, 00785, United States
# 38: Urb. Vista del Sol, Machete, Guayama, Puerto Rico, 00785, United States
# 39: Parque Interamericana, Machete, Guayama, Puerto Rico, 00785, United States
# 40: Calle 7, Urb. La Pradera, Machete, Guayama, Puerto Rico, 00785, United States
# 41: Parque Interamericana, Machete, Guayama, Puerto Rico, 00785, United States
# 42: Calle 6, Urb. La Pradera, Machete, Guayama, Puerto Rico, 00785, United States
# 43: Urb. Villa Universitaria, Machete, Guayama, Puerto Rico, 00785, United States
# 44: 72, Calle Arizona 2, San Felipe (Arizona), Barrio Pueblo, Arroyo, Puerto Rico, 00714, United States
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/http/client.py:1347, in HTTPConnection.getresponse(self)
#    1346 try:
# -> 1347     response.begin()
#    1348 except ConnectionError:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/http/client.py:307, in HTTPResponse.begin(self)
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/http/client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# timeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connectionpool.py:370, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     369 if isinstance(err, SocketTimeout):
# --> 370     raise ReadTimeoutError(
#     371         self, url, f"Read timed out. (read timeout={timeout_value})"
#     372     ) from err
#     374 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=17.9641943&lon=-66.3695947&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/geopy/adapters.py:482, in RequestsAdapter._request(self, url, timeout, headers)
#     481 try:
# --> 482     resp = self.session.get(url, timeout=timeout, headers=headers)
#     483 except Exception as error:
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=17.9641943&lon=-66.3695947&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# Cell In[6], line 25
#      20     return results.address if results else None
#      23 #new_df = df.head(100)
#      24 # apply the get_address function to each row in the DataFrame
# ---> 25 new_df['Address'] = new_df.apply(get_address, axis=1)
#      26 # save the updated DataFrame to a new CSV file
#      27 new_df.to_csv('locations_with_addresses.csv', index=False)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[6], line 17, in get_address(row)
#      15 location = (row['Latitude'], row['Longitude'])
#      16 # reverse geocode the coordinates
# ---> 17 results = geolocator.reverse(location, exactly_one=True)
#      18 # print the row number and address
#      19 print(f"{row.name}: {results}")
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/geopy/geocoders/nominatim.py:372, in Nominatim.reverse(self, query, exactly_one, timeout, language, addressdetails, zoom, namedetails)
#     370 logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     371 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 372 return self._call_geocoder(url, callback, timeout=timeout)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/geopy/geocoders/base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/geopy/adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#     474         return resp.json()
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/geopy/adapters.py:494, in RequestsAdapter._request(self, url, timeout, headers)
#     492         raise GeocoderServiceError(message)
#     493     else:
# --> 494         raise GeocoderUnavailable(message)
#     495 elif isinstance(error, requests.Timeout):
#     496     raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=17.9641943&lon=-66.3695947&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
import pandas as pd

df = pd.read_csv('coordenadas_v3.csv')

# separate the dataframe into dataframes of 100 rows each
dfs = [df.loc[i:i+99,:] for i in range(0, len(df), 100)]

# save each dataframe to a separate CSV file
for i, df in enumerate(dfs):
    print(f"Saving file {i}...")
    df.to_csv(f'files/coordenadas_v3_{i}.csv', index=False)
# Out:
# Saving file 0...
# Saving file 1...
# Saving file 2...
# Saving file 3...
# Saving file 4...
# Saving file 5...
# Saving file 6...
# Saving file 7...
# Saving file 8...
# Saving file 9...
# Saving file 10...
# Saving file 11...
# Saving file 12...
# Saving file 13...
# Saving file 14...
# Saving file 15...
# Saving file 16...
# Saving file 17...
US', 'gual': '259', 'ioc': 'USA', 'currency_alpha_code': 'USD', 'currency_country_name': 'UNITED STATES', 'currency_minor_unit': '2', 'currency_name': 'US Dollar', 'currency_code': '840', 'independent': 'Yes', 'capital': 'Washington', 'continent': 'NA', 'tld': '.us', 'languages': 'en-US,es-US,haw,fr', 'geoname_id': '6252001', 'edgar': ''}, 'datetime': {'date': '10/21/2023', 'date_time': '10/21/2023 14:17:36', 'date_time_txt': 'Saturday, October 21, 2023 14:17:36', 'date_time_wti': 'Sat, 21 Oct 2023 14:17:36 -0400', 'date_time_ymd': '2023-10-21T14:17:36-04:00', 'time': '14:17:36', 'month': '10', 'month_wilz': '10', 'month_abbr': 'Oct', 'month_full': 'October', 'month_days': '31', 'day': '21', 'day_wilz': '21', 'day_abbr': 'Sat', 'day_full': 'Saturday', 'year': '2023', 'year_abbr': '23', 'hour_12_wolz': '2', 'hour_12_wilz': '02', 'hour_24_wolz': '14', 'hour_24_wilz': '14', 'hour_am_pm': 'pm', 'minutes': '17', 'seconds': '36', 'week': '42', 'offset_seconds': '-14400', 'offset_minutes': '-240', 'offset_hours': '-4', 'offset_gmt': '-04:00', 'offset_tzid': 'America/New_York', 'offset_tzab': 'EDT', 'offset_tzfull': 'Eastern Daylight Time', 'tz_string': 'EST+5EDT,M3.2.0/2,M11.1.0/2', 'dst': 'true', 'dst_observes': 'true', 'timeday_spe': 'early_afternoon', 'timeday_gen': 'afternoon'}}}

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import usaddress

# Step 2: Read the CSV file into a DataFrame
df = pd.read_csv('files/coordenadas_v3_0.csv')

# Step 3: Create a geocoder object (Nominatim is a free geocoding service)
geolocator = Nominatim(user_agent="reverse_geocoder")

# Step 4: Reverse geocode each pair of latitude and longitude
def reverse_geocode(row):
    location = geolocator.reverse((row['latitude'], row['longitude']))
    print(f"{row.name}: {location}")
    return location.address if location else None
  
def parse_address(row):
    address = usaddress.parse(row['Reverse_Geocoded_Address'])
    if address:
        return address[0][0]
    else:
        return None

df['Reverse_Geocoded_Address'] = df.apply(reverse_geocode, axis=1)

df['Parsed_Address'] = df.apply(parse_address, axis=1)

# Step 5: You now have reverse geocoded results in a new column 'Reverse_Geocoded_Address'

# Step 6: Save the updated DataFrame to a new CSV file
df.to_csv('files/coordenadas_v3_0.csv', index=False)
# Out:
# 0: None
# 1: None
# 2: 55, Calle Sirena, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 3: Calle Palma, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 4: Calle Fragata, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 5: Calle Fragata, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 6: Jobos, Guayama, Puerto Rico, 00704, United States
# 7: Calle Espada, Playa Santa, Montalva, Guánica, Puerto Rico, 00647, United States
# 8: Calle 6, Nuevo Amanecer, Machete, Guayama, Puerto Rico, 00785, United States
# 9: Nuevo Amanecer, Machete, Guayama, Puerto Rico, 00785, United States
# 10: Calle A, Carenero, Guánica, Puerto Rico, 00653, United States
# 11: Nuevo Amanecer, Machete, Guayama, Puerto Rico, 00785, United States
# 12: Calle 2, Barrancas, Machete, Guayama, Puerto Rico, 00785, United States
# 13: Calle 2, Barrancas, Machete, Guayama, Puerto Rico, 00785, United States
Brisas del Mar 2, Barrio Pueblo, Guayama, Puerto Rico, 00785, United States
# 99: Calle Velero, Brisas del Mar 2, Barrio Pueblo, Guayama, Puerto Rico, United States
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 26
#      22         return None
#      24 df['Reverse_Geocoded_Address'] = df.apply(reverse_geocode, axis=1)
# ---> 26 df['Parsed_Address'] = df.apply(parse_address, axis=1)
#      28 # Step 5: You now have reverse geocoded results in a new column 'Reverse_Geocoded_Address'
#      29
#      30 # Step 6: Save the updated DataFrame to a new CSV file
#      31 df.to_csv('files/coordenadas_v3_0.csv', index=False)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[29], line 18, in parse_address(row)
#      17 def parse_address(row):
# ---> 18     address = usaddress.parse(row['Reverse_Geocoded_Address'])
#      19     if address:
#      20         return address[0][0]
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/usaddress/__init__.py:140, in parse(address_string)
#     139 def parse(address_string):
# --> 140     tokens = tokenize(address_string)
#     142     if not tokens:
#     143         return []
#
# File /opt/anaconda3/envs/solar/lib/python3.9/site-packages/usaddress/__init__.py:202, in tokenize(address_string)
#     200 if isinstance(address_string, bytes):
#     201     address_string = str(address_string, encoding='utf-8')
# --> 202 address_string = re.sub('(&#38;)|(&amp;)', '&', address_string)
#     203 re_tokens = re.compile(r"""
#     204 \(*\b[^\s,;#&()]+[.,;)\n]*   # ['ab. cd,ef '] -> ['ab.', 'cd,', 'ef']
#     205 |
#     206 [#&]                       # [^'#abc'] -> ['#']
#     207 """,
#     208                        re.VERBOSE | re.UNICODE)
#     210 tokens = re_tokens.findall(address_string)
#
# File /opt/anaconda3/envs/solar/lib/python3.9/re.py:210, in sub(pattern, repl, string, count, flags)
#     203 def sub(pattern, repl, string, count=0, flags=0):
#     204     """Return the string obtained by replacing the leftmost
#     205     non-overlapping occurrences of the pattern in string by the
#     206     replacement repl.  repl can be either a string or a callable;
#     207     if a string, backslash escapes in it are processed.  If it is
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object

# %%
for i in range(0, 100):
    print(f"Processing file {i}...")
    df = pd.read_csv(f'files/coordenadas_v3_{i}.csv')
    df['Reverse_Geocoded_Address'] = df.apply(reverse_geocode, axis=1)
    df.to_csv(f'files/coordenadas_v3_{i}.csv', index=False)

# %%
def parse_address(row):
    address = usaddress.parse(row['Reverse_Geocoded_Address'])
    if address is not None:
        return address[0][0]
    else:
        return None

# %%
# !pip install pygeocodio
# Out:
# Collecting pygeocodio
#   Obtaining dependency information for pygeocodio from https://files.pythonhosted.org/packages/d6/f2/654d0ea257cbaed72e73da13a92de9998705ccd988c9c739f5366c152ba1/pygeocodio-1.4.0-py3-none-any.whl.metadata
#   Downloading pygeocodio-1.4.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: requests>=1.0.0 in /opt/anaconda3/envs/solar/lib/python3.9/site-packages (from pygeocodio) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/solar/lib/python3.9/site-packages (from requests>=1.0.0->pygeocodio) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/solar/lib/python3.9/site-packages (from requests>=1.0.0->pygeocodio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/solar/lib/python3.9/site-packages (from requests>=1.0.0->pygeocodio) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/solar/lib/python3.9/site-packages (from requests>=1.0.0->pygeocodio) (2023.7.22)
# Downloading pygeocodio-1.4.0-py3-none-any.whl (11 kB)
# Installing collected packages: pygeocodio
# Successfully installed pygeocodio-1.4.0

# %%
API_KEY = "5c8cf6c84313d5148882f3e4416523f3f324648"
from geocodio import GeocodioClient
import pandas as pd
client = GeocodioClient(API_KEY)
import time

df = pd.read_csv('files/coordenadas_v3_0.csv')

for i, row in df.iterrows():
    time.sleep(2)
    print(f"Processing row {i}...")
    
    location = client.reverse((row['latitude'], row['longitude']))
    results = location.formatted_address
    
    if results:
        # parse the address
        parsed_address = client.parse(results)
        print(parsed_address)
        # add the address to the DataFrame
        df.loc[i, 'Reverse_Geocoded_Address'] = results
        # add the city to the DataFrame
        df.loc[i, 'StretNumber'] = parsed_address['address_components']['number']
        df.loc[i, 'StreetName'] = parsed_address['address_components']['street']
        df.loc[i, 'City'] = parsed_address['address_components']['city']
        df.loc[i, 'State'] = parsed_address['address_components']['state']
        df.loc[i, 'ZipCode'] = parsed_address['address_components']['zip']
    else:
        print("No results")
    
# save the updated DataFrame to a new CSV file
df.to_csv('files/coordenadas_v3_0.csv', index=False)
# Out:
# Processing row 0...
# No results
# Processing row 1...
# No results
# Processing row 2...
# {'address_components': {'number': '170', 'street': 'Pr- 324', 'formatted_street': 'Pr- 324', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '170 Pr- 324, Ensenada, PR 00647'}
# /var/folders/x9/pvlqkpyj4qb8xt82bcch_6w00000gn/T/ipykernel_96670/3139623563.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '170 Pr- 324, Ensenada, PR 00647' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'Reverse_Geocoded_Address'] = results
# /var/folders/x9/pvlqkpyj4qb8xt82bcch_6w00000gn/T/ipykernel_96670/3139623563.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '170' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'StretNumber'] = parsed_address['address_components']['number']
# /var/folders/x9/pvlqkpyj4qb8xt82bcch_6w00000gn/T/ipykernel_96670/3139623563.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Pr- 324' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'StreetName'] = parsed_address['address_components']['street']
# /var/folders/x9/pvlqkpyj4qb8xt82bcch_6w00000gn/T/ipykernel_96670/3139623563.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Ensenada' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'City'] = parsed_address['address_components']['city']
# /var/folders/x9/pvlqkpyj4qb8xt82bcch_6w00000gn/T/ipykernel_96670/3139623563.py:26: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'PR' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'State'] = parsed_address['address_components']['state']
# /var/folders/x9/pvlqkpyj4qb8xt82bcch_6w00000gn/T/ipykernel_96670/3139623563.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '00647' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'ZipCode'] = parsed_address['address_components']['zip']
# Processing row 3...
# {'address_components': {'number': '170', 'street': 'Pr- 324', 'formatted_street': 'Pr- 324', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '170 Pr- 324, Ensenada, PR 00647'}
# Processing row 4...
# {'address_components': {'number': '170', 'street': 'Pr- 324', 'formatted_street': 'Pr- 324', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '170 Pr- 324, Ensenada, PR 00647'}
# Processing row 5...
# {'address_components': {'number': '170', 'street': 'Pr- 324', 'formatted_street': 'Pr- 324', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '170 Pr- 324, Ensenada, PR 00647'}
# Processing row 6...
# {'address_components': {'number': '106', 'street': 'Cll D', 'formatted_street': 'Cll D', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '106 Cll D, Patillas, PR 00723'}
# Processing row 7...
# {'address_components': {'number': '170', 'street': 'Pr- 324', 'formatted_street': 'Pr- 324', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '170 Pr- 324, Ensenada, PR 00647'}
# Processing row 8...
# {'address_components': {'number': '52', 'street': 'Cll 2', 'formatted_street': 'Cll 2', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '52 Cll 2, Patillas, PR 00723'}
# Processing row 9...
# {'address_components': {'number': '52', 'street': 'Cll 2', 'formatted_street': 'Cll 2', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '52 Cll 2, Patillas, PR 00723'}
# Processing row 10...
# {'address_components': {'number': '81', 'street': 'Ave Esperanza Idrach', 'formatted_street': 'Ave Esperanza Idrach', 'city': 'Guanica', 'state': 'PR', 'zip': '00653', 'country': 'US'}, 'formatted_address': '81 Ave Esperanza Idrach, Guanica, PR 00653'}
# Processing row 11...
# {'address_components': {'number': '52', 'street': 'Cll 2', 'formatted_street': 'Cll 2', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '52 Cll 2, Patillas, PR 00723'}
# Processing row 12...
# {'address_components': {'number': '52', 'street': 'Cll 2', 'formatted_street': 'Cll 2', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '52 Cll 2, Patillas, PR 00723'}
# Processing row 13...
# {'address_components': {'number': '52', 'street': 'Cll 2', 'formatted_street': 'Cll 2', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '52 Cll 2, Patillas, PR 00723'}
# Processing row 14...
# {'address_components': {'number': '52', 'street': 'Cll 2', 'formatted_street': 'Cll 2', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '52 Cll 2, Patillas, PR 00723'}
# Processing row 15...
# {'address_components': {'number': '112', 'street': 'Cll D', 'formatted_street': 'Cll D', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '112 Cll D, Patillas, PR 00723'}
# Processing row 16...
# {'address_components': {'number': '120', 'street': 'Cll D', 'formatted_street': 'Cll D', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '120 Cll D, Patillas, PR 00723'}
# Processing row 17...
# {'address_components': {'number': '749', 'street': 'Cll Luz', 'formatted_street': 'Cll Luz', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '749 Cll Luz, Salinas, PR 00751'}
# Processing row 18...
# {'address_components': {'number': '582', 'street': 'Cll Girasol', 'formatted_street': 'Cll Girasol', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '582 Cll Girasol, Patillas, PR 00723'}
# Processing row 19...
# {'address_components': {'number': '55309', 'street': 'Cll Camelias', 'formatted_street': 'Cll Camelias', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '55309 Cll Camelias, Patillas, PR 00723'}
# Processing row 20...
# {'address_components': {'number': '749', 'street': 'Cll Luz', 'formatted_street': 'Cll Luz', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '749 Cll Luz, Salinas, PR 00751'}
# Processing row 21...
# {'address_components': {'number': '57', 'street': 'Cll Amapola', 'formatted_street': 'Cll Amapola', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '57 Cll Amapola, Patillas, PR 00723'}
# Processing row 22...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 23...
# {'address_components': {'number': '749', 'street': 'Cll Luz', 'formatted_street': 'Cll Luz', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '749 Cll Luz, Salinas, PR 00751'}
# Processing row 24...
# {'address_components': {'number': '103', 'street': 'Pr- 3', 'formatted_street': 'Pr- 3', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '103 Pr- 3, Patillas, PR 00723'}
# Processing row 25...
# {'address_components': {'number': '749', 'street': 'Cll Luz', 'formatted_street': 'Cll Luz', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '749 Cll Luz, Salinas, PR 00751'}
# Processing row 26...
# {'address_components': {'number': '749', 'street': 'Cll Luz', 'formatted_street': 'Cll Luz', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '749 Cll Luz, Salinas, PR 00751'}
# Processing row 27...
# {'address_components': {'number': '745', 'street': 'Cll Luz', 'formatted_street': 'Cll Luz', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '745 Cll Luz, Salinas, PR 00751'}
# Processing row 28...
# {'address_components': {'number': '745', 'street': 'Cll Luz', 'formatted_street': 'Cll Luz', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '745 Cll Luz, Salinas, PR 00751'}
# Processing row 29...
# {'address_components': {'number': '315', 'street': 'Cll 4', 'formatted_street': 'Cll 4', 'city': 'Santa Isabel', 'state': 'PR', 'zip': '00757', 'country': 'US'}, 'formatted_address': '315 Cll 4, Santa Isabel, PR 00757'}
# Processing row 30...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 31...
# {'address_components': {'number': '323', 'street': 'Cll 4', 'formatted_street': 'Cll 4', 'city': 'Santa Isabel', 'state': 'PR', 'zip': '00757', 'country': 'US'}, 'formatted_address': '323 Cll 4, Santa Isabel, PR 00757'}
# Processing row 32...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 33...
# {'address_components': {'number': '35', 'street': 'Cll Sierra', 'formatted_street': 'Cll Sierra', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '35 Cll Sierra, Salinas, PR 00751'}
# Processing row 34...
# {'address_components': {'number': '31', 'street': 'Cll 43', 'formatted_street': 'Cll 43', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '31 Cll 43, Patillas, PR 00723'}
# Processing row 35...
# {'address_components': {'number': '255', 'street': 'Cll B', 'formatted_street': 'Cll B', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '255 Cll B, Patillas, PR 00723'}
# Processing row 36...
# {'address_components': {'number': '20', 'street': 'Cll Arizona 2', 'formatted_street': 'Cll Arizona 2', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '20 Cll Arizona 2, Arroyo, PR 00714'}
# Processing row 37...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 38...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 39...
# {'address_components': {'number': '31', 'street': 'Cll 43', 'formatted_street': 'Cll 43', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '31 Cll 43, Patillas, PR 00723'}
# Processing row 40...
# {'address_components': {'number': '244', 'street': 'Cll 5', 'formatted_street': 'Cll 5', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '244 Cll 5, Patillas, PR 00723'}
# Processing row 41...
# {'address_components': {'number': '31', 'street': 'Cll 43', 'formatted_street': 'Cll 43', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '31 Cll 43, Patillas, PR 00723'}
# Processing row 42...
# {'address_components': {'number': '244', 'street': 'Cll 5', 'formatted_street': 'Cll 5', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '244 Cll 5, Patillas, PR 00723'}
# Processing row 43...
# {'address_components': {'number': '31', 'street': 'Cll 43', 'formatted_street': 'Cll 43', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '31 Cll 43, Patillas, PR 00723'}
# Processing row 44...
# {'address_components': {'number': '26', 'street': 'Cll Santa Teresa', 'formatted_street': 'Cll Santa Teresa', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '26 Cll Santa Teresa, Arroyo, PR 00714'}
# Processing row 45...
# {'address_components': {'number': '111', 'street': 'Cll 2', 'formatted_street': 'Cll 2', 'city': 'Santa Isabel', 'state': 'PR', 'zip': '00757', 'country': 'US'}, 'formatted_address': '111 Cll 2, Santa Isabel, PR 00757'}
# Processing row 46...
# {'address_components': {'number': '35', 'street': 'Cll Sierra', 'formatted_street': 'Cll Sierra', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '35 Cll Sierra, Salinas, PR 00751'}
# Processing row 47...
# {'address_components': {'number': '23', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '23 Cll 53, Patillas, PR 00723'}
# Processing row 48...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 49...
# {'address_components': {'number': '52', 'street': 'Cll Sierra', 'formatted_street': 'Cll Sierra', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '52 Cll Sierra, Salinas, PR 00751'}
# Processing row 50...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 51...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 52...
# {'address_components': {'number': '488', 'street': 'Cll Las', 'secondaryunit': 'Fl', 'secondarynumber': 'ES', 'formatted_street': 'Cll Las', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '488 Cll Las, Ensenada, PR 00647'}
# Processing row 53...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 54...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 55...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 56...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 57...
# {'address_components': {'number': '2', 'street': 'Cll Marcelino Cintron', 'formatted_street': 'Cll Marcelino Cintron', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '2 Cll Marcelino Cintron, Arroyo, PR 00714'}
# Processing row 58...
# {'address_components': {'number': '2', 'street': 'Cll Marcelino Cintron', 'formatted_street': 'Cll Marcelino Cintron', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '2 Cll Marcelino Cintron, Arroyo, PR 00714'}
# Processing row 59...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 60...
# {'address_components': {'number': '244', 'street': 'Cll 5', 'formatted_street': 'Cll 5', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '244 Cll 5, Patillas, PR 00723'}
# Processing row 61...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 62...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 63...
# {'address_components': {'number': '313', 'street': 'Cll F', 'formatted_street': 'Cll F', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '313 Cll F, Ensenada, PR 00647'}
# Processing row 64...
# {'address_components': {'number': '244', 'street': 'Cll 5', 'formatted_street': 'Cll 5', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '244 Cll 5, Patillas, PR 00723'}
# Processing row 65...
# {'address_components': {'number': '1', 'street': 'Cll D', 'formatted_street': 'Cll D', 'city': 'Ensenada', 'state': 'PR', 'zip': '00647', 'country': 'US'}, 'formatted_address': '1 Cll D, Ensenada, PR 00647'}
# Processing row 66...
# {'address_components': {'number': '35', 'street': 'Cll Sierra', 'formatted_street': 'Cll Sierra', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '35 Cll Sierra, Salinas, PR 00751'}
# Processing row 67...
# {'address_components': {'number': '244', 'street': 'Cll 5', 'formatted_street': 'Cll 5', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '244 Cll 5, Patillas, PR 00723'}
# Processing row 68...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 69...
# {'address_components': {'number': '244', 'street': 'Cll 5', 'formatted_street': 'Cll 5', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '244 Cll 5, Patillas, PR 00723'}
# Processing row 70...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 71...
# {'address_components': {'number': '86', 'street': 'Cll I', 'formatted_street': 'Cll I', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '86 Cll I, Arroyo, PR 00714'}
# Processing row 72...
# {'address_components': {'number': '86', 'street': 'Cll I', 'formatted_street': 'Cll I', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '86 Cll I, Arroyo, PR 00714'}
# Processing row 73...
# {'address_components': {'number': '6', 'street': 'Cll C', 'formatted_street': 'Cll C', 'city': 'Guanica', 'state': 'PR', 'zip': '00653', 'country': 'US'}, 'formatted_address': '6 Cll C, Guanica, PR 00653'}
# Processing row 74...
# {'address_components': {'number': '32', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '32 Cll 53, Patillas, PR 00723'}
# Processing row 75...
# {'address_components': {'number': '54', 'street': 'Cll San Marcos', 'formatted_street': 'Cll San Marcos', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '54 Cll San Marcos, Arroyo, PR 00714'}
# Processing row 76...
# {'address_components': {'number': '12', 'street': 'Cll F', 'formatted_street': 'Cll F', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '12 Cll F, Salinas, PR 00751'}
# Processing row 77...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 78...
# {'address_components': {'number': '19', 'street': 'Cll 15', 'formatted_street': 'Cll 15', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '19 Cll 15, Patillas, PR 00723'}
# Processing row 79...
# {'address_components': {'number': '15', 'street': 'Cll 8', 'formatted_street': 'Cll 8', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '15 Cll 8, Patillas, PR 00723'}
# Processing row 80...
# {'address_components': {'number': '35', 'street': 'Cll Sierra', 'formatted_street': 'Cll Sierra', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '35 Cll Sierra, Salinas, PR 00751'}
# Processing row 81...
# {'address_components': {'number': '269', 'street': 'Pr- 3', 'formatted_street': 'Pr- 3', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '269 Pr- 3, Patillas, PR 00723'}
# Processing row 82...
# {'address_components': {'number': '244', 'street': 'Cll 5', 'formatted_street': 'Cll 5', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '244 Cll 5, Patillas, PR 00723'}
# Processing row 83...
# {'address_components': {'number': '15', 'street': 'Cll 8', 'formatted_street': 'Cll 8', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '15 Cll 8, Patillas, PR 00723'}
# Processing row 84...
# {'address_components': {'number': '26', 'street': 'Pr- 541', 'formatted_street': 'Pr- 541', 'city': 'Santa Isabel', 'state': 'PR', 'zip': '00757', 'country': 'US'}, 'formatted_address': '26 Pr- 541, Santa Isabel, PR 00757'}
# Processing row 85...
# {'address_components': {'number': '19', 'street': 'Cll 15', 'formatted_street': 'Cll 15', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '19 Cll 15, Patillas, PR 00723'}
# Processing row 86...
# {'address_components': {'number': '23', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '23 Cll 53, Patillas, PR 00723'}
# Processing row 87...
# {'address_components': {'number': '52', 'street': 'Cll Sierra', 'formatted_street': 'Cll Sierra', 'city': 'Salinas', 'state': 'PR', 'zip': '00751', 'country': 'US'}, 'formatted_address': '52 Cll Sierra, Salinas, PR 00751'}
# Processing row 88...
# {'address_components': {'number': '66', 'street': 'Cll H', 'formatted_street': 'Cll H', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '66 Cll H, Arroyo, PR 00714'}
# Processing row 89...
# {'address_components': {'number': '66', 'street': 'Cll H', 'formatted_street': 'Cll H', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '66 Cll H, Arroyo, PR 00714'}
# Processing row 90...
# {'address_components': {'number': '23', 'street': 'Cll 53', 'formatted_street': 'Cll 53', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '23 Cll 53, Patillas, PR 00723'}
# Processing row 91...
# {'address_components': {'number': '15', 'street': 'Cll 8', 'formatted_street': 'Cll 8', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '15 Cll 8, Patillas, PR 00723'}
# Processing row 92...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 93...
# {'address_components': {'number': '900', 'street': 'Cll L', 'formatted_street': 'Cll L', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '900 Cll L, Patillas, PR 00723'}
# Processing row 94...
# {'address_components': {'number': '19', 'street': 'Cll 15', 'formatted_street': 'Cll 15', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '19 Cll 15, Patillas, PR 00723'}
# Processing row 95...
# {'address_components': {'number': '54', 'street': 'Cll San Marcos', 'formatted_street': 'Cll San Marcos', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '54 Cll San Marcos, Arroyo, PR 00714'}
# Processing row 96...
# {'address_components': {'number': '15', 'street': 'Cll 8', 'formatted_street': 'Cll 8', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '15 Cll 8, Patillas, PR 00723'}
# Processing row 97...
# {'address_components': {'number': '86', 'street': 'Cll I', 'formatted_street': 'Cll I', 'city': 'Arroyo', 'state': 'PR', 'zip': '00714', 'country': 'US'}, 'formatted_address': '86 Cll I, Arroyo, PR 00714'}
# Processing row 98...
# {'address_components': {'number': '15', 'street': 'Cll 8', 'formatted_street': 'Cll 8', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '15 Cll 8, Patillas, PR 00723'}
# Processing row 99...
# {'address_components': {'number': '6', 'street': 'Cll 42', 'formatted_street': 'Cll 42', 'city': 'Patillas', 'state': 'PR', 'zip': '00723', 'country': 'US'}, 'formatted_address': '6 Cll 42, Patillas, PR 00723'}

# %%
import pandas as pd

df1 = pd.read_csv('data.csv', encoding='utf-8')
df2 = pd.read_csv('acs2017_county_data.csv', encoding='utf-8')

merged_df = pd.merge(df1, df2, how='left', left_on='County', right_on='County', suffixes=('_left', '_right'))

# %%
merged_df.head()
# Out:
#     latitude  longitude   Latitude  Longitude  Accuracy Score   Accuracy Type  \
# 0  18.150260 -66.759120  18.164923 -66.726929            0.12  nearest_street
# 1  18.165141 -66.727228  18.164923 -66.726929            0.97  nearest_street
# 2  18.166733 -66.722569  18.166493 -66.723462            0.95  nearest_street
# 3  18.173333 -66.708333  18.162257 -66.718086            0.25  nearest_street
# 4  18.168942 -66.791578  18.168942 -66.791578            1.00   nearest_place
#
#   Number                  Street  Unit Type  Unit Number  ... Walk  \
# 0     10          Cll San Felipe        NaN          NaN  ...  5.7
# 1     10          Cll San Felipe        NaN          NaN  ...  5.7
# 2      9  Cll Fernando Rodriguez        NaN          NaN  ...  5.7
# 3     41      Cll John F Kennedy        NaN          NaN  ...  5.7
# 4    NaN                     NaN        NaN          NaN  ...  5.7
#
#   OtherTransp WorkAtHome  MeanCommute Employed PrivateWork  PublicWork  \
# 0         1.1        1.5         28.9   3719.0        57.2        33.7
# 1         1.1        1.5         28.9   3719.0        57.2        33.7
# 2         1.1        1.5         28.9   3719.0        57.2        33.7
# 3         1.1        1.5         28.9   3719.0        57.2        33.7
# 4         1.1        1.5         28.9   3719.0        57.2        33.7
#
#   SelfEmployed  FamilyWork  Unemployment
# 0          9.0         0.0          40.9
# 1          9.0         0.0          40.9
# 2          9.0         0.0          40.9
# 3          9.0         0.0          40.9
# 4          9.0         0.0          40.9
#
# [5 rows x 52 columns]

# %%
merged_df.to_csv('data_v1.csv', index=False)
